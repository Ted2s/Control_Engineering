# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd  /content/drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone "https://github.com/Ted2s/Control_Engineering.git"
# Out:
# Cloning into 'Control_Engineering'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 27 (delta 0), reused 9 (delta 0), pack-reused 0
# Receiving objects: 100% (27/27), 5.49 KiB | 803.00 KiB/s, done.

# %%
cd  Control_Engineering/
# Out:
# /content/drive/MyDrive/Colab Notebooks/Control_Engineering

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Control_Engineering/.git/

# %%
# !git config --global user.email "kdragon201062@gmail.com"
# !git config --global user.name "Ted2s"

# %%
# !git add .
# !git commit -m "Edit Readme.md"
# Out:
# [main 5a6e6a6] Edit Readme.md
#  1 file changed, 3 insertions(+), 2 deletions(-)

# %%
# !git remote add ControlEngineering https://Ted2s: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@github.com/Ted2s/Control_Engineering.git

# %%
# !git push -u ControlEngineering main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Writing objects: 100% (3/3), 266 bytes | 53.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Ted2s/Control_Engineering.git
#    a428bbf..5a6e6a6  main -> main
# Branch 'main' set up to track remote branch 'main' from 'ControlEngineering'.
